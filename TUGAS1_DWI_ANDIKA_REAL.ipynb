# %% [markdown]
# <a href="https://colab.research.google.com/github/igustingurahdwiandikaputra-code/Tugas1/blob/main/TUGAS1_DWI_ANDIKA_REAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

#input nillai mahasiswa
nilai_mahasiswa = []
print("Masukkan nilai mahasiswa:")
for i in range(10):
    angka = int(input("Masukkan angka: "))
    nilai_mahasiswa.append(angka)

#max,min,sum
nilai_tertinggi = max(nilai_mahasiswa)
nilai_terendah = min(nilai_mahasiswa)
rata_rata = sum(nilai_mahasiswa) / len(nilai_mahasiswa)

#htiung kwlulusan
lulus = [n for n in nilai_mahasiswa if n >= 60]
tidak_lulus = [n for n in nilai_mahasiswa if n < 60]
jumlah_lulus = len(lulus)
jumlah_tidak_lulus = len(tidak_lulus)

#Hasil
print(f"Nilai Tertinggi: {nilai_tertinggi}")
print(f"Nilai Terendah : {nilai_terendah}")
print(f"Rata-rata      : {rata_rata:.2f}")
print(f"Jumlah Lulus   : {jumlah_lulus}")
print(f"Tidak Lulus    : {jumlah_tidak_lulus}")

#Grafik
fig, ax = plt.subplots(1, 2, figsize=(14, 5))

#Grafik Nilai Tertinggi & Terendah
ax[0].bar(['Terendah', 'Tertinggi'], [nilai_terendah, nilai_tertinggi], color=['skyblue', 'salmon'])
ax[0].set_title('Perbandingan Nilai')
ax[0].set_ylabel('Skor')

#Grafik Kelulusan
labels = ['Lulus >=60', 'Tidak Lulus <60']
sizes = [jumlah_lulus, jumlah_tidak_lulus]
ax[1].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'salmon'])
ax[1].set_title('Persentase Kelulusan Mahasiswa')

plt.tight_layout()
plt.show()
# Out:
# Masukkan nilai mahasiswa:
# Masukkan angka: 70
# Masukkan angka: 70
# Masukkan angka: 80
# Masukkan angka: 80
# Masukkan angka: 80
# Masukkan angka: 50
# Masukkan angka: 60
# Masukkan angka: 70
# Masukkan angka: 80
# Masukkan angka: 30
# Nilai Tertinggi: 80
# Nilai Terendah : 30
# Rata-rata      : 67.00
# Jumlah Lulus   : 8
# Tidak Lulus    : 2
